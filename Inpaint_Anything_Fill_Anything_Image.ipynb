# %% [markdown]
# <a href="https://colab.research.google.com/github/protocol-streams/research/blob/main/Inpaint_Anything_Fill_Anything_Image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python --version
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.8 1
# !sudo update-alternatives --config python3

# %%
# !python3 --version
# !sudo apt install python3-pip

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd '/content/drive/MyDrive'
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive

# %%
# %cd 'Inpaint-Anything'
# !pip install torch torchvision torchaudio
# !pip install -e segment_anything
# !pip install diffusers transformers accelerate scipy safetensors
# Out:
# /content/drive/MyDrive/Inpaint-Anything
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 619.9 MB 13 kB/s
# ...
#      |████████████████████████████████| 33.8 MB 1.3 MB/s
# ...
#      |████████████████████████████████| 4.4 MB 53.9 MB/s
# ...
#      |████████████████████████████████| 173.2 MB 23 kB/s
# ...
#      |████████████████████████████████| 54.6 MB 95 kB/s
# ...
#      |████████████████████████████████| 5.7 MB 68.7 MB/s
# ...
#      |████████████████████████████████| 133 kB 61.1 MB/s
# ...
#      |████████████████████████████████| 2.1 MB 55.8 MB/s
# ...
#      |████████████████████████████████| 21.0 MB 1.2 MB/s
# ...
#      |████████████████████████████████| 11.8 MB 32.6 MB/s
# ...
#      |████████████████████████████████| 557.1 MB 7.6 kB/s
# ...
#      |████████████████████████████████| 317.1 MB 21 kB/s
# ...
#      |████████████████████████████████| 63.2 MB 3.1 kB/s
# ...
#      |████████████████████████████████| 849 kB 55.7 MB/s
# ...

# %%
#!pip list
# !pip install opencv-python
# !pip install matplotlib
# !pip install ipykernel
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 61.8 MB 129 kB/s
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 9.2 MB 8.8 MB/s
# ...
#      |████████████████████████████████| 300 kB 46.5 MB/s
# ...
#      |████████████████████████████████| 1.0 MB 36.1 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 45.2 MB/s
# ...
#      |████████████████████████████████| 247 kB 44.7 MB/s
# ...
#      |████████████████████████████████| 98 kB 2.0 MB/s
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 152 kB 8.6 MB/s
# ...
#      |████████████████████████████████| 3.1 MB 49.8 MB/s
# ...
#      |████████████████████████████████| 93 kB 1.2 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 39.9 MB/s
# ...

# %%
# !python fill_anything.py \
    --input_img ./example/fill-anything/sample2.png \
    --coords_type key_in \
    --point_coords 750 500 \
    --point_labels 1 \
    --text_prompt "an astronaut on a bench" \
    --dilate_kernel_size 10 \
    --output_dir ./results \
    --sam_model_type "vit_b" \
    --sam_ckpt ./pretrained_models/sam_vit_b_01ec64.pth
# Out:
# ...
# Fetching 13 files:   0% 0/13 [00:00<?, ?it/s]
# ...
# Fetching 13 files:   8% 1/13 [00:00<00:02,  4.67it/s]
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
#
# ...
#
#
#
# ...
#
#
#
# ...
#
#
#
# ...
# Fetching 13 files:  23% 3/13 [00:00<00:01,  6.53it/s]
# ...
#
#
# ...
#
# ...
#
#
#
#
# ...
#
#
#
# ...
#
# ...
#
# ...
#
#
# ...
#
# ...
#
#
# ...
#
# ...
#
#
# ...
#
# ...
#
#
# ...
#
# ...
#
#
# ...
#
# ...
#
#
# ...
#
# ...
#
#
# ...
#
# ...
#
#
# ...
#
# ...
#
# ...
#
#
# ...
#
# ...
#
#
# ...
#
# ...
#
#
# ...
#
# ...
#
#
# ...
#
# ...
#
#
# ...
#
# ...
#
#
# ...
#
# ...
#
#
# ...
#
#
# ...
#
# ...
#
#
# ...
#
# ...
#
# ...
#
#
# ...
#
# ...
#
#
# ...
#
# ...
#
#
# ...
#
# ...
#
#
# ...
#
# ...
#
# ...
#
#
# ...
#
# ...
#
#
# ...
#
# ...
#
#
# ...
#
# ...
#
#
# ...
#
# ...
#
#
# ...
#
# ...
#
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
#
# Fetching 13 files:  38% 5/13 [00:32<01:06,  8.28s/it]
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
